# %%
#Importing basic tools
import pandas as pd
import matplotlib.pyplot as plt
import numpy as num

# %%
#Reading csv file
df = pd.read_csv (r'covid.csv')

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/30/20  5/1/20  5/2/20  5/3/20  5/4/20  \
# 0        0        0        0  ...     2171    2335    2469    2704    2894
# 1        0        0        0  ...      773     782     789     795     803
# 2        0        0        0  ...     4006    4154    4295    4474    4648
# 3        0        0        0  ...      745     745     747     748     750
# 4        0        0        0  ...       27      30      35      35      35
#
#    5/5/20  5/6/20  5/7/20  5/8/20  5/9/20
# ...

# %%
#Searching for Pakistan
dfp = df.loc[df['Country/Region'] == 'Pakistan']

# %%
dfp
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 177            NaN       Pakistan  30.3753  69.3451        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  4/30/20  5/1/20  5/2/20  5/3/20  \
# 177        0        0        0        0  ...    16817   18114   19103   20084
#
#      5/4/20  5/5/20  5/6/20  5/7/20  5/8/20  5/9/20
# 177   20941   22049   24073   24644   26435   28736
#
# [1 rows x 113 columns]

# %%
dfp1 = dfp.loc[:, '1/22/20':'5/9/20']

# %%
dfp1
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# 177        0        0        0        0        0        0        0        0
#
#      1/30/20  1/31/20  ...  4/30/20  5/1/20  5/2/20  5/3/20  5/4/20  5/5/20  \
# 177        0        0  ...    16817   18114   19103   20084   20941   22049
#
#      5/6/20  5/7/20  5/8/20  5/9/20
# 177   24073   24644   26435   28736
#
# [1 rows x 109 columns]

# %%
rowp = dfp1.iloc[0]

# %%
#Plotting Pakistan
plt.title('Pakistan')
plt.xlabel('Dates')
plt.ylabel('People')
rowp.plot(kind='line', color='green')

# %%
#Searching for India
dfit = df.loc[df['Country/Region'] == 'India']

# %%
dfit
# Out:
#     Province/State Country/Region   Lat  Long  1/22/20  1/23/20  1/24/20  \
# 131            NaN          India  21.0  78.0        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  4/30/20  5/1/20  5/2/20  5/3/20  5/4/20  \
# 131        0        0        0  ...    34863   37257   39699   42505   46437
#
#      5/5/20  5/6/20  5/7/20  5/8/20  5/9/20
# 131   49400   52987   56351   59695   62808
#
# [1 rows x 113 columns]

# %%
dfit1 = dfit.loc[:, '1/22/20':'5/9/20']

# %%
rowit = dfit1.iloc[0]

# %%
#Plotting India
plt.title('India')
plt.xlabel('Dates')
plt.ylabel('People')
rowit.plot(kind='line', color='red')

# %%
rowp2 = dfp2.iloc[0]
rowit2 = dfit2.iloc[0]

# %%
#Plot comparing India and Pakistan
plt.title('India and Pakistan')
plt.xlabel('Dates')
plt.ylabel('People')
plt.plot(rowp2,'g-', rowit2, 'r-')
plt.legend(['Pakistan','India'], loc='upper left')
plt.show()

# %%
#fetching Columns
dfpi = df.loc[ [177 , 131] , : ]
dfpi.head()

# %%
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 177            NaN       Pakistan  30.3753  69.3451        0        0
# 131            NaN          India  21.0000  78.0000        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  4/30/20  5/1/20  5/2/20  5/3/20  \
# 177        0        0        0        0  ...    16817   18114   19103   20084
# 131        0        0        0        0  ...    34863   37257   39699   42505
#
#      5/4/20  5/5/20  5/6/20  5/7/20  5/8/20  5/9/20
# 177   20941   22049   24073   24644   26435   28736
# 131   46437   49400   52987   56351   59695   62808
#
# [2 rows x 113 columns]

# %%
#Cleaning Data
df11 = dfpi.loc[:, '1/22/20':'5/9/20']

# %%
df11.head()
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# 177        0        0        0        0        0        0        0        0
# 131        0        0        0        0        0        0        0        0
#
#      1/30/20  1/31/20  ...  4/30/20  5/1/20  5/2/20  5/3/20  5/4/20  5/5/20  \
# 177        0        0  ...    16817   18114   19103   20084   20941   22049
# 131        1        1  ...    34863   37257   39699   42505   46437   49400
#
#      5/6/20  5/7/20  5/8/20  5/9/20
# 177   24073   24644   26435   28736
# 131   52987   56351   59695   62808
#
# [2 rows x 109 columns]

# %%
dfs = df11.iloc[:, ::6]
               
dfs.head()
# Out:
#      1/22/20  1/28/20  2/3/20  2/9/20  2/15/20  2/21/20  2/27/20  3/4/20  \
# 177        0        0       0       0        0        0        2       5
# 131        0        0       3       3        3        3        3      28
#
#      3/10/20  3/16/20  3/22/20  3/28/20  4/3/20  4/9/20  4/15/20  4/21/20  \
# 177       16      136      776     1495    2686    4489     6383     9565
# 131       56      119      396      987    2567    6725    12322    20080
#
#      4/27/20  5/3/20  5/9/20
# 177    13915   20084   28736
# 131    29451   42505   62808

# %%
dfs
# Out:
#      1/22/20  1/28/20  2/3/20  2/9/20  2/15/20  2/21/20  2/27/20  3/4/20  \
# 177        0        0       0       0        0        0        2       5
# 131        0        0       3       3        3        3        3      28
#
#      3/10/20  3/16/20  3/22/20  3/28/20  4/3/20  4/9/20  4/15/20  4/21/20  \
# 177       16      136      776     1495    2686    4489     6383     9565
# 131       56      119      396      987    2567    6725    12322    20080
#
#      4/27/20  5/3/20  5/9/20
# 177    13915   20084   28736
# 131    29451   42505   62808

# %%
dfs1 = dfs.loc[:, '2/27/20':'5/9/20']
dfs1.head()
# Out:
#      2/27/20  3/4/20  3/10/20  3/16/20  3/22/20  3/28/20  4/3/20  4/9/20  \
# 177        2       5       16      136      776     1495    2686    4489
# 131        3      28       56      119      396      987    2567    6725
#
#      4/15/20  4/21/20  4/27/20  5/3/20  5/9/20
# 177     6383     9565    13915   20084   28736
# 131    12322    20080    29451   42505   62808

# %%
dfs2 = dfs1
dfs2.head()
# Out:
#      2/27/20  3/4/20  3/10/20  3/16/20  3/22/20  3/28/20  4/3/20  4/9/20  \
# 177        2       5       16      136      776     1495    2686    4489
# 131        3      28       56      119      396      987    2567    6725
#
#      4/15/20  4/21/20  4/27/20  5/3/20  5/9/20
# 177     6383     9565    13915   20084   28736
# 131    12322    20080    29451   42505   62808

# %%
#Applying Population multiplier ratio 
## India has 1.35B and Pakistan has 200M. ratio= 1350/2 = 6.75
dfs3 = dfs2.loc[177,:] *6.75
dfs3.head()
# Out:
# 2/27/20      13.50
# 3/4/20       33.75
# 3/10/20     108.00
# 3/16/20     918.00
# 3/22/20    5238.00
# Name: 177, dtype: float64

# %%
#Plotting
Pakistan = dfs3
India = dfs2.loc[131,:]
plt.title('India and Pakistan (Ratio)')
plt.xlabel('Dates')
plt.ylabel('People')
plt.rcParams['figure.figsize'] = [15, 8]
plt.plot(Pakistan,'g-', India, 'r-')
plt.legend(['Pakistan','India'], loc='upper left')
plt.show()
